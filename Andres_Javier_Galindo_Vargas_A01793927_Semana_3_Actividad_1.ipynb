# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo63-databost/blob/main/Andres_Javier_Galindo_Vargas_A01793927_Semana_3_Actividad_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Andres Javier Galindo Vargas A01793927
# # Carlos Jesús Peñaloza Julio -- A01793931
#
#
# profesor : JOBIS
# fecha :04-OCT-2022

# %% [markdown]
# #Semana 3 - Actividad 1
# * Parte 1: Fundamentos de bases de datos
# * Parte 2: Selección y limpieza de los Datos en Python
# * Parte 3: Preparación de los datos

# %% [markdown]
# # Parte 1: Fundamentos de bases de datos.
#
# * Fundamentos de bases de datos y para ciencia de datos.
# * Fundamentos de almacenes de datos (Data Warehouse) para ciencia de datos.
#
#
# 1. Aspectos teóricos
#
# como tal veo que un Data Warehouse, se ve como una base de datos corporativa, ya que es muy importante en la manera en que puedo generar  analizar la informacion y mostrar informes acerca de ella . con los cual nos permite de gran manera  tomar mejores decisiones como punto focal de todos los procesos de Business Intelligence; ya que se ha convertido en una parte fundamental para la recolección y análisis de datos dentro de todo el entorno de trabajo Big Data.
#
# 2. beneficios bodegas
#
# * almacena datos historicos
#
# * integracion de areas de la empresa , ya que la informacion esta centralizada
#
# * aumento de rentabilidad
#
# 3. Caracteristicas
#
# * Integrado
# * Variante en el tiempo
# * No volátil

# %% [markdown]
# # Limpieza de datos -Parte 2: Selección y limpieza de los Datos en Python.

# %%
# import de las librerias
import pandas as pd
import numpy as np

# %% [markdown]
# leer la base de datos (DataFrame) y hacer el rename de las column por temas de entendimiento:

# %% [markdown]
# * X1: Monto del crédito otorgado (dólar NT): incluye tanto el crédito de consumo individual como su crédito familiar (complementario).
# * X2: Género (1 = masculino; 2 = femenino).
# * X3: Educación (1 = posgrado; 2 = universidad; 3 = secundaria; 4 = otros).
# * X4: Estado civil (1 = casado; 2 = soltero; 3 = otros).
# *  X5: Edad (año).
# *  X6 - X11: Historial de pagos pasados
# * X12-X17: Importe del estado de cuenta (dólar NT)
# * X18-X23: Monto del pago anterior (dólar NT)

# %%
df  = pd.read_csv('/content/Creditos.csv')
df
# Out:
#           ID      X1   X2   X3   X4    X5   X6   X7   X8   X9  ...      X15  \
# 0          1   20000  2.0  2.0  1.0  24.0  2.0  2.0 -1.0 -1.0  ...      0.0
# 1          2  120000  2.0  2.0  2.0  26.0 -1.0  2.0  0.0  0.0  ...   3272.0
# 2          3   90000  2.0  2.0  2.0  34.0  0.0  0.0  0.0  0.0  ...  14331.0
# 3          4   50000  2.0  2.0  1.0  37.0  0.0  0.0  0.0  0.0  ...  28314.0
# 4          5   50000  1.0  2.0  1.0  57.0 -1.0  0.0 -1.0  0.0  ...  20940.0
# ...      ...     ...  ...  ...  ...   ...  ...  ...  ...  ...  ...      ...
# 29995  29996  220000  1.0  3.0  1.0  39.0  0.0  0.0  0.0  0.0  ...  88004.0
# 29996  29997  150000  1.0  3.0  2.0  43.0 -1.0 -1.0 -1.0 -1.0  ...   8979.0
# 29997  29998   30000  1.0  2.0  2.0  37.0  4.0  3.0  2.0 -1.0  ...  20878.0
# 29998  29999   80000  1.0  3.0  1.0  41.0  1.0 -1.0  0.0  0.0  ...  52774.0
# 29999  30000   50000  1.0  2.0  1.0  46.0  0.0  0.0  0.0  0.0  ...  36535.0
#
# ...

# %% [markdown]
# Copy de los datos

# %%
creditosT=df.copy()
creditosT
# Out:
#           ID      X1   X2   X3   X4    X5   X6   X7   X8   X9  ...      X15  \
# 0          1   20000  2.0  2.0  1.0  24.0  2.0  2.0 -1.0 -1.0  ...      0.0
# 1          2  120000  2.0  2.0  2.0  26.0 -1.0  2.0  0.0  0.0  ...   3272.0
# 2          3   90000  2.0  2.0  2.0  34.0  0.0  0.0  0.0  0.0  ...  14331.0
# 3          4   50000  2.0  2.0  1.0  37.0  0.0  0.0  0.0  0.0  ...  28314.0
# 4          5   50000  1.0  2.0  1.0  57.0 -1.0  0.0 -1.0  0.0  ...  20940.0
# ...      ...     ...  ...  ...  ...   ...  ...  ...  ...  ...  ...      ...
# 29995  29996  220000  1.0  3.0  1.0  39.0  0.0  0.0  0.0  0.0  ...  88004.0
# 29996  29997  150000  1.0  3.0  2.0  43.0 -1.0 -1.0 -1.0 -1.0  ...   8979.0
# 29997  29998   30000  1.0  2.0  2.0  37.0  4.0  3.0  2.0 -1.0  ...  20878.0
# 29998  29999   80000  1.0  3.0  1.0  41.0  1.0 -1.0  0.0  0.0  ...  52774.0
# 29999  30000   50000  1.0  2.0  1.0  46.0  0.0  0.0  0.0  0.0  ...  36535.0
#
# ...

# %% [markdown]
# Renombramiento

# %%
creditosT.rename(columns = {'X1' : 'Monto', 
                     'X2' : 'Género',
                     'X3' : 'Educación',
                     'X4' : 'Estado_civil',
                     'X5' : 'Edad',
                     'X6' : 'H_sep',
                     'X7' : 'H_ago',
                     'X8' : 'H_jul',
                     'X9' : 'H_jun',
                     'X10' : 'H_may',
                     'X11': 'H_apr',
                     'X12': 'impo_sep',
                     'X13': 'impo_ago',
                     'X14': 'impo_jul',
                     'X15': 'impo_jun',
                     'X16': 'impo_may',
                     'X17': 'impo_apr',
                     'X18': 'mont_sep',
                     'X19': 'mont_ago',
                     'X20': 'mont_jul',
                     'X21': 'mont_jun',
                     'X22': 'mont_may',
                     'X23': 'mont_apr'})
# Out:
#           ID   Monto  Género  Educación  Estado_civil  Edad  H_sep  H_ago  \
# 0          1   20000     2.0        2.0           1.0  24.0    2.0    2.0
# 1          2  120000     2.0        2.0           2.0  26.0   -1.0    2.0
# 2          3   90000     2.0        2.0           2.0  34.0    0.0    0.0
# 3          4   50000     2.0        2.0           1.0  37.0    0.0    0.0
# 4          5   50000     1.0        2.0           1.0  57.0   -1.0    0.0
# ...      ...     ...     ...        ...           ...   ...    ...    ...
# 29995  29996  220000     1.0        3.0           1.0  39.0    0.0    0.0
# 29996  29997  150000     1.0        3.0           2.0  43.0   -1.0   -1.0
# 29997  29998   30000     1.0        2.0           2.0  37.0    4.0    3.0
# 29998  29999   80000     1.0        3.0           1.0  41.0    1.0   -1.0
# 29999  30000   50000     1.0        2.0           1.0  46.0    0.0    0.0
#
#        H_jul  H_jun  ...  impo_jun  impo_may  impo_apr  mont_sep  mont_ago  \
# ...

# %% [markdown]
# Para verificar, Datos Nulos:

# %%
# validacion de datos faltantes
creditosT.isnull().values.any()
# Out:
# True

# %%
creditosT.isnull().any()
# Out:
# ID              False
# Monto           False
# Género           True
# Educación        True
# Estado_civil     True
# Edad             True
# H_sep            True
# H_ago            True
# H_jul            True
# H_jun            True
# H_may            True
# H_apr            True
# impo_sep         True
# impo_ago         True
# impo_jul         True
# impo_jun         True
# impo_may         True
# impo_apr         True
# mont_sep         True
# mont_ago         True
# mont_jul         True
# mont_jun         True
# mont_may         True
# mont_apr         True
# Y                True
# dtype: bool

# %% [markdown]
# Validamos la cantidad

# %%
creditosT.isnull().sum().sort_values(ascending=True)
# Out:
# ID               0
# Monto            0
# Género           1
# Educación        2
# Estado_civil     2
# H_sep            3
# Y                3
# H_ago            5
# mont_apr         5
# Edad             5
# H_jul            7
# mont_jul         8
# mont_sep         8
# H_jun            9
# mont_ago         9
# impo_apr        10
# mont_may        11
# mont_jun        11
# impo_sep        11
# impo_ago        11
# impo_jul        13
# H_apr           14
# impo_jun        15
# H_may           16
# impo_may        17
# dtype: int64

# %% [markdown]
# ### Tratamiento de los datos Faltantes
#
# se eliminan por la cantidad de datos son pocos 196

# %%
creditosT.dropna(inplace = True)

# %%
creditosT.isna().values.any()
# Out:
# False

# %%
creditosT
# Out:
#           ID   Monto  Género  Educación  Estado_civil  Edad  H_sep  H_ago  \
# 0          1   20000     2.0        2.0           1.0  24.0    2.0    2.0
# 1          2  120000     2.0        2.0           2.0  26.0   -1.0    2.0
# 2          3   90000     2.0        2.0           2.0  34.0    0.0    0.0
# 3          4   50000     2.0        2.0           1.0  37.0    0.0    0.0
# 4          5   50000     1.0        2.0           1.0  57.0   -1.0    0.0
# ...      ...     ...     ...        ...           ...   ...    ...    ...
# 29995  29996  220000     1.0        3.0           1.0  39.0    0.0    0.0
# 29996  29997  150000     1.0        3.0           2.0  43.0   -1.0   -1.0
# 29997  29998   30000     1.0        2.0           2.0  37.0    4.0    3.0
# 29998  29999   80000     1.0        3.0           1.0  41.0    1.0   -1.0
# 29999  30000   50000     1.0        2.0           1.0  46.0    0.0    0.0
#
#        H_jul  H_jun  ...  impo_jun  impo_may  impo_apr  mont_sep  mont_ago  \
# ...

# %%
creditosT.describe()
# Out:
#                  ID           Monto        Género     Educación  Estado_civil  \
# count  29958.000000    29958.000000  29958.000000  29958.000000  29958.000000
# mean   15005.550504   167555.900928      1.604012      1.853094      1.551739
# std     8654.547473   129737.299088      0.489070      0.790471      0.521952
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7516.250000    50000.000000      1.000000      1.000000      1.000000
# 50%    15005.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22497.750000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                Edad         H_sep         H_ago         H_jul         H_jun  \
# count  29958.000000  29958.000000  29958.000000  29958.000000  29958.000000
# mean      35.483443     -0.017124     -0.134021     -0.166767     -0.221110
# ...

# %% [markdown]
# ### Para seleccionar las columnas de la base de datos, puede usar la siguiente codigos:

# %%
creditosT.columns
# Out:
# Index(['ID', 'Monto', 'Género', 'Educación', 'Estado_civil', 'Edad', 'H_sep',
#        'H_ago', 'H_jul', 'H_jun', 'H_may', 'H_apr', 'impo_sep', 'impo_ago',
#        'impo_jul', 'impo_jun', 'impo_may', 'impo_apr', 'mont_sep', 'mont_ago',
#        'mont_jul', 'mont_jun', 'mont_may', 'mont_apr', 'Y'],
#       dtype='object')

# %% [markdown]
# #Parte 3: Preparación de los datos
#
# * ¿Qué datos considero mas importantes? ¿Por qué?
# RTA: los datos mas importantes : genero , Educación, valores historicos , monto. los considero importantes ya que  las relaciones entre las variables es buena y son importantes en encontrar las variable objetivo
#
# *  ¿Se eliminaron o reemplazaron datos nulos? ¿Qué se hizo y por qué?
#
# RTA: se eliminaron ya que son pocos datos y no superan el 5% de los mismos
#
# *  ¿Es necesario ordenar los datos para el análisis? Sí / No / ¿Por qué?
#
# RTA: si es necesario, la finalidad es tener una metrica mas ajustada del los datos y una visualizacion mas efectiva al momento de realizar el analisis en base a los cambios que presenten los datos
#
# *  ¿Existen problemas de formato que deban solucionar antes del proceso de modelado? Sí / No / Por qué.
#
# RTA: si, existen problemas de datos con informacion nula, existe informacion con datos en cero que no otorga ninguna informacion importante
#
# * ¿Qué ajustes se realizaron en el proceso de limpieza de datos (agregar, integrar, eliminar, modificar registros (filas), cambiar atributos (columnas)?
#
# RTA: eliminar datos faltantes, ordenamiento de las columnas y renombramientos de las mismas.
