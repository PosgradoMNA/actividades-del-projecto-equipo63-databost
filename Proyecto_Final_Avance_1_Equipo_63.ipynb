# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo63-databost/blob/main/Proyecto_Final_Avance_1_Equipo_63.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROYECTO FINAL - AVANCE 1**
#
# Andres Javier Galindo -- A01793927
#
# Carlos Jesús Peñaloza Julio -- A01793931

# %% [markdown]
# 1. El nombre que caracteriza el conjunto de datos es:
# USDA-ARS Colorado Maize Water Productivity Dataset 2012-2013
#
# 2. Fue generado por el Departamento de Agricultura de los Estados Unidos.
#
# 3. Se encontraron en la misma base de datos un archivo .csv y otro .xml:
#
# https://us-usda-gov.linked.data.world/d/1acabe89-2436-428d-ab7b-fa17b725bf55/file/comma-separated-values-file-2.csv
#
# https://us-usda-gov.linked.data.world/d/399b1624-d167-46f7-ab4e-03ab505ffae1/file/ms-excel-file-1.xml
#
# 4. Describe el conjunto de datos. ¿Qué datos contiene?
#
# El archivo .csv contiene la descripción de las variables que están en las diferentes hojas del .xml, las que son de nuestro interés están relacionadas con el clima, por ejemplo, tenemos la dirección del viento, las precipitaciones, la temperatura ambiente, la humedad relativa y por supuesto la medida por unidad de tiempo. También tenemos la capacidad del suelo que podemos ver en la segunda tabla; aquí nos interesa conocer la capacidad para aplicar algún tratamiento como fertilizantes o insecticidas, otra variable puede ser el porcentaje de agua en el suelo.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
#
#
# 5. ¿Cuáles son algunas de las preguntas de investigación que podría responder con estos datos? Enumere al menos OCHO (no responda las preguntas).
# Respuesta:
#     1. ¿Cómo se podría hacer predicción de un cultivo de maíz por medio de un algoritmo supervisado?
#     2. ¿Cómo se podría mejorar el sistema de riego o de irrigación del suelo usando machine learning?
#     3. Teniendo en cuenta el comportamiento el efecto del clima, ¿Es posible que el algoritmo de predicción logre aportar en la mejora de la producción de maíz?
#     4. ¿Cómo podría mejorarse el gasto del recurso hídrico haciendo análisis de grandes volúmenes de datos provenientes de la tecnificación del cultivo de maíz?
#     5. ¿Es la capacidad del suelo importante en el rendimiento de un cultivo?
#     6. ¿Podríamos predecir la dirección del viento y la temperatura ambiente para incrementar en un 10% el rendimiento del cultivo?
#     7. Con el análisis del data set, ¿Cómo se puede determinar la mejor temporada del año para sembrar?
#     8. ¿Es la ciencia de datos capaz de demostrar que la tecnificación que se aplica actualmente a los cultivos ha quedado obsoleta?
#     9. ¿Cómo la ciencia de datos y Internet de las Cosas complementan la tecnificación actual para mejorar la producción de cualquier cultivo en cualquien clima?
#
#
#
# 6. ¿Qué actor (empresa, sector de la sociedad, organismo descentralizado, gobierno, etc.) estaría interesado en las preguntas mencionadas que identificó?
#
# Partiendo de que estamos considerando la mejora de la producción de maíz aplicando algoritmo de Machine Learning y que la analítica estaría al alcance del dueño del cultivo para tomar mejores decisiones, la empresa privada sería la más interesada, seguidos en igual proporción del Ministerio de Agricultura así como las entidades relacionadas con ésta.
